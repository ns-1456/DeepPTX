# %% [markdown]
# # Phase 4: Interactive Gradio Demo
#
# Launch the DeepPTX decompiler as a web app. Works locally (Mac/Linux) or on Colab with a shareable link.

# %%
# --- Clone repo on Colab ---
import os
if os.path.exists("/content"):
    # %cd /content
    # !rm -rf /content/DeepPTX
    # !git clone https://github.com/ns-1456/DeepPTX.git /content/DeepPTX
    # %cd /content/DeepPTX
    # !pip install -q gradio graphviz

# %%
import sys, os

IN_COLAB = os.path.exists("/content")
REPO_ROOT = "/content/DeepPTX" if IN_COLAB else os.path.abspath("..")
if REPO_ROOT not in sys.path:
    sys.path.insert(0, REPO_ROOT)

from demo.app import app

# share=True gives a public URL on Colab; locally opens in browser
app.launch(share=IN_COLAB)
