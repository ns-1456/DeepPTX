# %% [markdown]
# # Phase 4: Interactive Gradio Demo
#
# Run the Gradio app from this notebook to get a shareable link (e.g. for Colab).

# %%
# --- Clone repo on Colab ---
import os
if not os.path.exists("/content/DeepPTX"):
    # !git clone https://github.com/ns-1456/DeepPTX.git /content/DeepPTX
# %cd /content/DeepPTX

# !pip install -q gradio graphviz

import sys
REPO_ROOT = "/content/DeepPTX" if os.path.exists("/content/DeepPTX") else os.path.abspath("..")
if REPO_ROOT not in sys.path:
    sys.path.insert(0, REPO_ROOT)

from demo.app import app

app.launch(share=True)
